# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Iris.csv")

# %%
df.groupby("Species").mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
df.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
df.groupby("Species").median()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5            5.0           3.4           1.50
# Iris-versicolor   75.5            5.9           2.8           4.35
# Iris-virginica   125.5            6.5           3.0           5.55
#
#                  PetalWidthCm
# Species
# Iris-setosa               0.2
# Iris-versicolor           1.3
# Iris-virginica            2.0

# %%
np.percentile(df["SepalLengthCm"], 25, interpolation="midpoint")
# Out:
# 5.1

# %%
df.groupby("Species")

# %%
df.groupby("Species").first()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa        1            5.1           3.5            1.4           0.2
# Iris-versicolor   51            7.0           3.2            4.7           1.4
# Iris-virginica   101            6.3           3.3            6.0           2.5

# %%
df.groupby("Species").get_group("Iris-setosa")
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
df.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
df["Id"].std()
# Out:
# 43.445367992456916

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df["SepalLengthCm"].std()
# Out:
# 0.8280661279778629

# %%
df["SepalWidthCm"].std()
# Out:
# 0.4335943113621737

# %%
df["PetalLengthCm"].std()
# Out:
# 1.7644204199522617

# %%
df["PetalWidthCm"].std()
# Out:
# 0.7631607417008414

# %% [markdown]
# ASSIGNMENT 3 PART 1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("age_income.csv")
df
# Out:
#     ID   Age Group  Income
# 0    0       Young   25000
# 1    1  Middle Age   54000
# 2    2         Old   60000
# 3    3       Young   15000
# 4    4       Young   45000
# 5    5       Young   65000
# 6    6       Young   70000
# 7    7       Young   30000
# 8    8  Middle Age   27000
# 9    9       Young   23000
# 10  10       Young   48000
# 11  11         Old   52000
# 12  12       Young   33000
# 13  13         Old   80000
# 14  14         Old   75000
# 15  15         Old   35000
# 16  16  Middle Age   29000
# 17  17  Middle Age   57000
# 18  18         Old   43000
# 19  19  Middle Age   56000
# 20  20         Old   63000
# 21  21         Old   32000
# 22  22         Old   45000
# 23  23         Old   89000
# 24  24  Middle Age   90000
# 25  25  Middle Age   93000
# 26  26       Young   80000
# 27  27       Young   87000
# 28  28       Young   38000
# 29  29       Young   23000
# 30  30  Middle Age   38900
# 31  31  Middle Age   53200
# 32  32         Old   43800
# ...

# %%
df.groupby("Age Group")

# %%
df
# Out:
#     ID   Age Group  Income
# 0    0       Young   25000
# 1    1  Middle Age   54000
# 2    2         Old   60000
# 3    3       Young   15000
# 4    4       Young   45000
# 5    5       Young   65000
# 6    6       Young   70000
# 7    7       Young   30000
# 8    8  Middle Age   27000
# 9    9       Young   23000
# 10  10       Young   48000
# 11  11         Old   52000
# 12  12       Young   33000
# 13  13         Old   80000
# 14  14         Old   75000
# 15  15         Old   35000
# 16  16  Middle Age   29000
# 17  17  Middle Age   57000
# 18  18         Old   43000
# 19  19  Middle Age   56000
# 20  20         Old   63000
# 21  21         Old   32000
# 22  22         Old   45000
# 23  23         Old   89000
# 24  24  Middle Age   90000
# 25  25  Middle Age   93000
# 26  26       Young   80000
# 27  27       Young   87000
# 28  28       Young   38000
# 29  29       Young   23000
# 30  30  Middle Age   38900
# 31  31  Middle Age   53200
# 32  32         Old   43800
# ...

# %%
df.describe()
# Out:
#              ID        Income
# count  50.00000     50.000000
# mean   24.50000  50966.000000
# std    14.57738  21096.683268
# min     0.00000  15000.000000
# 25%    12.25000  33475.000000
# 50%    24.50000  46850.000000
# 75%    36.75000  65400.000000
# max    49.00000  93000.000000

# %%
df.std()
# Out:
# C:\Users\Mrudul Patel\AppData\Local\Temp2\ipykernel_19244\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# ID           14.577380
# Income    21096.683268
# dtype: float64

# %%
df.min()
# Out:
# ID                    0
# Age Group    Middle Age
# Income            15000
# dtype: object

# %%
df.max()
# Out:
# ID              49
# Age Group    Young
# Income       93000
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\Mrudul Patel\AppData\Local\Temp2\ipykernel_19244\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# ID           24.5
# Income    50966.0
# dtype: float64

# %%
df.mode()
# Out:
#     ID Age Group   Income
# 0    0       Old  23000.0
# 1    1       NaN  25600.0
# 2    2       NaN  45000.0
# 3    3       NaN  65400.0
# 4    4       NaN  80000.0
# 5    5       NaN      NaN
# 6    6       NaN      NaN
# 7    7       NaN      NaN
# 8    8       NaN      NaN
# 9    9       NaN      NaN
# 10  10       NaN      NaN
# 11  11       NaN      NaN
# 12  12       NaN      NaN
# 13  13       NaN      NaN
# 14  14       NaN      NaN
# 15  15       NaN      NaN
# 16  16       NaN      NaN
# 17  17       NaN      NaN
# 18  18       NaN      NaN
# 19  19       NaN      NaN
# 20  20       NaN      NaN
# 21  21       NaN      NaN
# 22  22       NaN      NaN
# 23  23       NaN      NaN
# 24  24       NaN      NaN
# 25  25       NaN      NaN
# 26  26       NaN      NaN
# 27  27       NaN      NaN
# 28  28       NaN      NaN
# 29  29       NaN      NaN
# 30  30       NaN      NaN
# 31  31       NaN      NaN
# 32  32       NaN      NaN
# 33  33       NaN      NaN
# ...

# %%
gk = df.groupby("Age Group")

# %%
gk

# %%
for age_group, income in gk:
    print(age_group, " ", income)
# Out:
# Middle Age       ID   Age Group  Income
# 1    1  Middle Age   54000
# 8    8  Middle Age   27000
# 16  16  Middle Age   29000
# 17  17  Middle Age   57000
# 19  19  Middle Age   56000
# 24  24  Middle Age   90000
# 25  25  Middle Age   93000
# 30  30  Middle Age   38900
# 31  31  Middle Age   53200
# 33  33  Middle Age   25600
# 34  34  Middle Age   65400
# 40  40  Middle Age   45700
# 43  43  Middle Age   65400
# 46  46  Middle Age   34900
# 49  49  Middle Age   51700
# Old       ID Age Group  Income
# 2    2       Old   60000
# 11  11       Old   52000
# 13  13       Old   80000
# 14  14       Old   75000
# 15  15       Old   35000
# 18  18       Old   43000
# 20  20       Old   63000
# 21  21       Old   32000
# 22  22       Old   45000
# 23  23       Old   89000
# 32  32       Old   43800
# 35  35       Old   76800
# 36  36       Old   89700
# 37  37       Old   41800
# 39  39       Old   25600
# 41  41       Old   35600
# 44  44       Old   67800
# 45  45       Old   24500
# ...
